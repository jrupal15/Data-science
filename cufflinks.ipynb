# %%
import cufflinks as cf
import plotly.plotly as py
import numpy as np
import plotly.tools as tls
import IPython
import pandas as pd
r=tls.embed('https://plot.ly/~cufflinks/8')
#Ipython.display.IFrame()
r
# Out:
# /home/rupal15/.local/lib/python3.5/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~cufflinks/8.embed" height="525" width="100%"></iframe>

# %%
dodo = cf.datagen.lines()

# %%
dodo
# Out:
#               MCV.MY     VPJ.PE     OVL.EY    PSR.OK     LBT.EP
# 2015-01-01  0.767586  -0.732809   1.500937 -0.573621  -1.289046
# 2015-01-02  0.855912  -0.895221   1.824483  0.825783  -1.455689
# 2015-01-03  1.103036  -0.294529   2.493305 -0.006483  -1.131381
# 2015-01-04  1.552379   1.236205   2.322370 -1.734561  -1.803606
# 2015-01-05  4.308137   3.421322   3.740519  0.069478  -2.767311
# 2015-01-06  6.857811   4.608796   4.344739 -1.218103  -2.484703
# 2015-01-07  7.474947   4.256524   4.493325 -1.170742  -2.209377
# 2015-01-08  7.609974   5.564047   1.885269 -0.412754  -3.296914
# 2015-01-09  8.154560   6.065254   4.207697 -0.460860  -3.889300
# 2015-01-10  8.670910   5.898051   6.496071 -0.312182  -4.806465
# 2015-01-11  8.270571   6.004084   6.655083 -1.558088  -4.743924
# 2015-01-12  7.166444   5.015968   7.590154 -2.562064  -4.160024
# 2015-01-13  7.567256   4.645074   8.516571 -4.066032  -2.749802
# 2015-01-14  7.748896   3.386835   9.886781 -4.675464  -2.708426
# ...

# %%
py.iplot([{
    'x': dodo.index,
    'y': dodo[col],
    'name': col
}  for col in dodo.columns], filename='cufflinks/simple-line')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cda371625f0d> in <module>
# ----> 1 py.iplot([{
#       2     'x': dodo.index,
#       3     'y': dodo[col],
#       4     'name': col
#       5 }  for col in dodo.columns], filename='cufflinks/simple-line')
#
# NameError: name 'py' is not defined

# %%
import pandas as pd
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
df.scatter_matrix(filename='cufflinks/scatter-matrix', world_readable=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e5f1c6cb26f8> in <module>
#       1
#       2 import pandas as pd
# ----> 3 df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
#       4 df.scatter_matrix(filename='cufflinks/scatter-matrix', world_readable=True)
#       5
#
# NameError: name 'np' is not defined

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot 
cf.go_offline()

# %%
import pandas as pd

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
dt=pd.DataFrame(np.random.randn(200,10),columns='a b c d e f g h i j'.split())

# %%
dt
# Out:
#             a         b         c         d         e         f         g  \
# 0    0.607840  2.041103  1.264578  0.339183  0.615557 -0.436157  2.684585
# 1    0.061850 -0.186202  0.332184 -0.949050  1.195260  0.322313  0.255872
# 2   -1.511049  0.669104 -0.739168 -0.107936 -0.612280 -1.271248 -0.536167
# 3    1.010884  0.679504 -0.342354  0.551256 -0.952546 -0.163258  1.286489
# 4    0.353664  1.281232  0.109680 -1.185864  1.161792  0.044253  0.709074
# 5    0.081277 -0.749405  0.103470  0.689818 -1.230320 -0.415799 -0.853305
# 6   -0.807361 -1.908355 -2.421374 -0.365168 -0.280753  0.143295 -1.346601
# 7    0.028575 -2.061959 -0.011108 -1.129520 -1.227774  1.674596 -0.046893
# 8    0.244509  0.528176 -1.025092  0.879934 -1.107057  0.690367 -0.079268
# 9   -0.173654 -0.348534 -1.934133 -0.214716  1.314684  1.072366 -0.715064
# 10   1.332296  0.375714 -2.073651 -1.779486 -0.802829  0.572078  1.395741
# 11  -0.709553  0.515467 -0.168742  0.639763  0.353084 -1.975337 -0.323356
# ...

# %%
dt.iplot()
# Out:
# <div>
#
#
#             <div id="48ab3017-766a-458d-bc51-19ce17b84bb6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("48ab3017-766a-458d-bc51-19ce17b84bb6")) {
#                     Plotly.newPlot(
#                         '48ab3017-766a-458d-bc51-19ce17b84bb6',
# ...

# %%
dt.iplot(kind ='scatter', x ='a', y ='b', mode ='markers')
# Out:
# <div>
#
#
#             <div id="3efd4b67-e5e4-4052-b210-833c2fee749a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3efd4b67-e5e4-4052-b210-833c2fee749a")) {
#                     Plotly.newPlot(
#                         '3efd4b67-e5e4-4052-b210-833c2fee749a',
# ...

# %%
df3 = pd.DataFrame({'x':[1, 2, 3, 4, 5], 
                    'y':[10, 20, 30, 20, 10], 
                    'z':[500, 400, 300, 200, 100]})

# %%
df3
# Out:
#    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  20  200
# 4  5  10  100

# %%
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="e41ba8d2-63f2-48d6-8ab6-a26f33cb3962" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e41ba8d2-63f2-48d6-8ab6-a26f33cb3962")) {
#                     Plotly.newPlot(
#                         'e41ba8d2-63f2-48d6-8ab6-a26f33cb3962',
# ...
